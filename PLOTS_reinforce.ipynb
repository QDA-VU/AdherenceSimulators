# %% [markdown]
# Making sure seeds are the same

# %%
import pickle


seeds_reinforce_llm = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce/seeds.pkl', 'rb'))
seeds_smoking_llm = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_smoking/seeds.pkl', 'rb'))
seeds_many_baselines = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/seeds.pkl', 'rb'))
print("seeds_reinforce", seeds_reinforce_llm) # should be the same seeds
print("seeds_smoking", seeds_smoking_llm)
print("seeds_many_baselines", seeds_many_baselines)
# Out:
# seeds_reinforce [136044, 248239, 714933]
# seeds_smoking [136044, 248239, 714933]
# seeds_many_baselines [136044, 248239, 714933]

# %% [markdown]
# Making sure all algs had the same test set

# %%
true_vals_reinforce_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce/true_run_1.pkl', 'rb'))
true_vals_smoking_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_smoking/true_run_1.pkl', 'rb'))
true_vals_reinforce_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce/true_run_2.pkl', 'rb'))
true_vals_smoking_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_smoking/true_run_2.pkl', 'rb'))
true_vals_reinforce_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce/true_run_3.pkl', 'rb'))
true_vals_smoking_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_smoking/true_run_3.pkl', 'rb'))


true_vals_gan_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_GAN/true_run_1.pkl', 'rb'))
true_vals_gan_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_GAN/true_run_2.pkl', 'rb'))
true_vals_gan_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_GAN/true_run_3.pkl', 'rb'))

true_vals_nde_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_NDE/true_run_1.pkl', 'rb'))
true_vals_nde_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_NDE/true_run_2.pkl', 'rb'))
true_vals_nde_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_NDE/true_run_3.pkl', 'rb'))

true_vals_lr_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Linear Regression/true_run_1.pkl', 'rb'))
true_vals_lr_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Linear Regression/true_run_2.pkl', 'rb'))
true_vals_lr_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Linear Regression/true_run_3.pkl', 'rb'))

true_vals_majority_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_majority_class/true_run_1.pkl', 'rb'))
true_vals_majority_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_majority_class/true_run_2.pkl', 'rb'))
true_vals_majority_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_majority_class/true_run_3.pkl', 'rb'))

true_lasso_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/true_run_1.pkl', 'rb'))
true_lasso_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/true_run_2.pkl', 'rb'))
true_lasso_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/true_run_3.pkl', 'rb'))

true_lasso_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/true_run_1.pkl', 'rb'))
true_lasso_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/true_run_2.pkl', 'rb'))
true_lasso_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/true_run_3.pkl', 'rb'))

true_ridge_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Ridge Regression/true_run_1.pkl', 'rb'))
true_ridge_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Ridge Regression/true_run_2.pkl', 'rb'))
true_ridge_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Ridge Regression/true_run_3.pkl', 'rb'))

true_random_forest_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Random Forest/true_run_1.pkl', 'rb'))
true_random_forest_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Random Forest/true_run_2.pkl', 'rb'))
true_random_forest_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Random Forest/true_run_3.pkl', 'rb'))


print("true_vals_gan_run1", true_vals_gan_run1)
print("true_vals_smoking_run1", true_vals_smoking_run1)
print("true_vals_nde_run1", true_vals_nde_run1)
print("true_vals_lr_run1", true_vals_lr_run1)
print("true_vals_majority_run1", true_vals_majority_run1)
print()

print("true_vals_gan_run2", true_vals_gan_run2)
print("true_vals_smoking_run2", true_vals_smoking_run2)
print("true_vals_nde_run2", true_vals_nde_run2)
print("true_vals_lr_run2", true_vals_lr_run2)
print("true_vals_majority_run2", true_vals_majority_run2)
print()

print("true_vals_gan_run3", true_vals_gan_run3)
print("true_vals_smoking_run3", true_vals_smoking_run3)
print("true_vals_nde_run3", true_vals_nde_run3)
print("true_vals_lr_run3", true_vals_lr_run3)
print("true_vals_majority_run3", true_vals_majority_run3)
print()
# Out:
# true_vals_gan_run1 [0. 0. 0. ... 0. 0. 0.]
# ...

# %% [markdown]
# # Performance plot on Smoking

# %% [markdown]
# ### Extracting predictions

# %%
preds_majority_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_majority_class/pred_run_1.pkl', 'rb'))
preds_majority_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_majority_class/pred_run_2.pkl', 'rb'))
preds_majority_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_majority_class/pred_run_3.pkl', 'rb'))

preds_mean_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_mean/pred_run_1.pkl', 'rb'))
preds_mean_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_mean/pred_run_2.pkl', 'rb'))
preds_mean_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_mean/pred_run_3.pkl', 'rb'))


preds_reinforce_llms_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce/pred_run_1.pkl', 'rb'))
preds_reinforce_llms_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce/pred_run_2.pkl', 'rb'))
preds_reinforce_llms_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce/pred_run_3.pkl', 'rb'))

preds_gan_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_GAN/pred_run_1.pkl', 'rb'))
preds_gan_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_GAN/pred_run_2.pkl', 'rb'))
preds_gan_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_GAN/pred_run_3.pkl', 'rb'))

preds_nde_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_NDE/pred_run_1.pkl', 'rb'))
preds_nde_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_NDE/pred_run_2.pkl', 'rb'))
preds_nde_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_NDE/pred_run_3.pkl', 'rb'))

preds_lr_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Linear Regression/pred_run_1.pkl', 'rb'))
preds_lr_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Linear Regression/pred_run_2.pkl', 'rb'))
preds_lr_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Linear Regression/pred_run_3.pkl', 'rb'))

preds_lasso_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/pred_run_1.pkl', 'rb'))
preds_lasso_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/pred_run_2.pkl', 'rb'))
preds_lasso_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/pred_run_3.pkl', 'rb'))

preds_lasso_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/pred_run_1.pkl', 'rb'))
preds_lasso_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/pred_run_2.pkl', 'rb'))
preds_lasso_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Lasso Regression/pred_run_3.pkl', 'rb'))

preds_ridge_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Ridge Regression/pred_run_1.pkl', 'rb'))
preds_ridge_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Ridge Regression/pred_run_2.pkl', 'rb'))
preds_ridge_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Ridge Regression/pred_run_3.pkl', 'rb'))

preds_random_forest_run1 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Random Forest/pred_run_1.pkl', 'rb'))
preds_random_forest_run2 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Random Forest/pred_run_2.pkl', 'rb'))
preds_random_forest_run3 = pickle.load(open('/Users/andreilixandru/Downloads/NDEs-for-adherence-main/RUNS_reinforce_many_baselines/RUNS_Random Forest/pred_run_3.pkl', 'rb'))

# %%
from sklearn.metrics import mean_squared_error

mse_majority_run1 = mean_squared_error(true_vals_majority_run1, preds_majority_run1)
mse_majority_run2 = mean_squared_error(true_vals_majority_run2, preds_majority_run2)
mse_majority_run3 = mean_squared_error(true_vals_majority_run3, preds_majority_run3)
majority_mse_all_runs = [mse_majority_run1, mse_majority_run2, mse_majority_run3]

mse_mean_run1 = mean_squared_error(true_vals_majority_run1, preds_mean_run1)
mse_mean_run2 = mean_squared_error(true_vals_majority_run2, preds_mean_run2)
mse_mean_run3 = mean_squared_error(true_vals_majority_run3, preds_mean_run3)
mean_mse_all_runs = [mse_mean_run1, mse_mean_run2, mse_mean_run3]


mse_smoking_llms_run1 = mean_squared_error(true_vals_reinforce_run1, preds_reinforce_llms_run1)
mse_smoking_llms_run2 = mean_squared_error(true_vals_reinforce_run2, preds_reinforce_llms_run2)
mse_smoking_llms_run3 = mean_squared_error(true_vals_reinforce_run3, preds_reinforce_llms_run3)
smoking_llms_mse_all_runs = [mse_smoking_llms_run1, mse_smoking_llms_run2, mse_smoking_llms_run3]

mse_gan_run1 = mean_squared_error(true_vals_gan_run1, preds_gan_run1)
mse_gan_run2 = mean_squared_error(true_vals_gan_run2, preds_gan_run2)
mse_gan_run3 = mean_squared_error(true_vals_gan_run3, preds_gan_run3)
gan_mse_all_runs = [mse_gan_run1, mse_gan_run2, mse_gan_run3]
mse_nde_run1 = mean_squared_error(true_vals_nde_run1, preds_nde_run1)
mse_nde_run2 = mean_squared_error(true_vals_nde_run2, preds_nde_run2)
mse_nde_run3 = mean_squared_error(true_vals_nde_run3, preds_nde_run3)
nde_mse_all_runs = [mse_nde_run1, mse_nde_run2, mse_nde_run3]

mse_lr_run1 = mean_squared_error(true_vals_lr_run1, preds_lr_run1)
mse_lr_run2 = mean_squared_error(true_vals_lr_run2, preds_lr_run2)
mse_lr_run3 = mean_squared_error(true_vals_lr_run3, preds_lr_run3)
lr_mse_all_runs = [mse_lr_run1, mse_lr_run2, mse_lr_run3]

mse_lasso_run1 = mean_squared_error(true_lasso_run1, preds_lasso_run1)
mse_lasso_run2 = mean_squared_error(true_lasso_run2, preds_lasso_run2)
mse_lasso_run3 = mean_squared_error(true_lasso_run3, preds_lasso_run3)
lasso_mse_all_runs = [mse_lasso_run1, mse_lasso_run2, mse_lasso_run3]

mse_ridge_run1 = mean_squared_error(true_ridge_run1, preds_ridge_run1)
mse_ridge_run2 = mean_squared_error(true_ridge_run2, preds_ridge_run2)
mse_ridge_run3 = mean_squared_error(true_ridge_run3, preds_ridge_run3)
ridge_mse_all_runs = [mse_ridge_run1, mse_ridge_run2, mse_ridge_run3]

mse_random_forest_run1 = mean_squared_error(true_random_forest_run1, preds_random_forest_run1)
mse_random_forest_run2 = mean_squared_error(true_random_forest_run2, preds_random_forest_run2)
mse_random_forest_run3 = mean_squared_error(true_random_forest_run3, preds_random_forest_run3)
random_forest_mse_all_runs = [mse_random_forest_run1, mse_random_forest_run2, mse_random_forest_run3]

mses_across_methods = {
    "Majority": majority_mse_all_runs,
    "Smoking LLMs": smoking_llms_mse_all_runs,
    "GAN": gan_mse_all_runs,
    "NDE": nde_mse_all_runs,
    "Linear Regression": lr_mse_all_runs,
    "Lasso Regression": lasso_mse_all_runs,
    "Ridge Regression": ridge_mse_all_runs,
    "Random Forest": random_forest_mse_all_runs
}

import matplotlib.pyplot as plt
import numpy as np

# 1. Your dictionary of data
# (Assuming these variables are already defined in your environment)
mses_across_methods = {
    "Majority": majority_mse_all_runs,
    "Mean": mean_mse_all_runs,
    "LLMs": smoking_llms_mse_all_runs,
    "GAN": gan_mse_all_runs,
    "NDE": nde_mse_all_runs,
    "Linear Regression": lr_mse_all_runs,
    "Lasso Regression": lasso_mse_all_runs,
    "Ridge Regression": ridge_mse_all_runs,
    "Random Forest": random_forest_mse_all_runs
}

# 2. Extract ordered lists for the plot
ordered_methods_for_xticks = list(mses_across_methods.keys())
mse_lists_ordered = list(mses_across_methods.values())

# 3. Initialize the figure
fig, ax = plt.subplots(figsize=(12, 6))

# 4. Create the violin plot
parts = ax.violinplot(
    mse_lists_ordered,
    positions=np.arange(len(ordered_methods_for_xticks)),
    showmeans=True,
    showmedians=False,
    showextrema=True
)

# 5. Custom coloring for violins
# I added 'pink' to your list so there are 8 distinct colors for your 8 methods
violin_colors = ['gray', 'dodgerblue', 'orange', 'green', 'purple', 'red', 'teal', 'pink']
for i, pc in enumerate(parts['bodies']):
    color = violin_colors[i % len(violin_colors)]
    pc.set_facecolor(color)
    pc.set_alpha(0.7)
    pc.set_edgecolor('black')

# 6. Customize the style of the lines (means, mins, maxes)
for partname in ('cbars', 'cmins', 'cmaxes', 'cmeans', 'cmedians'):
    vp = parts.get(partname)
    if vp is not None:
        vp.set_edgecolor('black')
        vp.set_linewidth(1.6)

# 7. Add the jittered scatter points for each run
for i, mse_list in enumerate(mse_lists_ordered):
    # scale controls how wide the jitter spreads horizontally
    xvals = np.random.normal(loc=i, scale=0.05, size=len(mse_list))
    ax.scatter(xvals, mse_list, color='k', alpha=0.5, zorder=10, label='_nolegend_')

# plot simple baselines as dotted lines
ax.axhline(np.mean(majority_mse_all_runs), color='gray', linestyle=':', linewidth=2)
ax.axhline(np.mean(mean_mse_all_runs), color='gray', linestyle=':', linewidth=2)

# 8. Set up the axes ticks, labels, and titles
ax.set_xticks(np.arange(len(ordered_methods_for_xticks)))
ax.set_xticklabels(ordered_methods_for_xticks, rotation=45, ha='right')

ax.set_title("Mean Squared Error (MSE) Distribution Across Methods", fontsize=14)
ax.set_ylabel("MSE", fontsize=12)
ax.set_xlabel("Method", fontsize=12)

# Prevent x-axis labels from being cut off
plt.tight_layout()

# %%
majority_mse_all_runs = [mse_majority_run1, mse_majority_run2, mse_majority_run3]
mean_mse_all_runs = [mse_mean_run1, mse_mean_run2, mse_mean_run3]
smoking_llms_mse_all_runs = [mse_smoking_llms_run1, mse_smoking_llms_run2, mse_smoking_llms_run3]
gan_mse_all_runs = [mse_gan_run1, mse_gan_run2, mse_gan_run3]
nde_mse_all_runs = [mse_nde_run1, mse_nde_run2, mse_nde_run3]
lr_mse_all_runs = [mse_lr_run1, mse_lr_run2, mse_lr_run3]
lasso_mse_all_runs = [mse_lasso_run1, mse_lasso_run2, mse_lasso_run3]
ridge_mse_all_runs = [mse_ridge_run1, mse_ridge_run2, mse_ridge_run3]
random_forest_mse_all_runs = [mse_random_forest_run1, mse_random_forest_run2, mse_random_forest_run3]

print("Majority:", "{:.3f}".format(np.mean(majority_mse_all_runs)), "±", "{:.3f}".format(np.std(majority_mse_all_runs)))
print("Mean:", "{:.3f}".format(np.mean(mean_mse_all_runs)), "±", "{:.3f}".format(np.std(mean_mse_all_runs)))
print("LLMs:", "{:.3f}".format(np.mean(smoking_llms_mse_all_runs)), "±", "{:.3f}".format(np.std(smoking_llms_mse_all_runs)))
print("GAN:", "{:.3f}".format(np.mean(gan_mse_all_runs)), "±", "{:.3f}".format(np.std(gan_mse_all_runs)))
print("NDE:", "{:.3f}".format(np.mean(nde_mse_all_runs)), "±", "{:.3f}".format(np.std(nde_mse_all_runs)))
print("Linear Regression:", "{:.3f}".format(np.mean(lr_mse_all_runs)), "±", "{:.3f}".format(np.std(lr_mse_all_runs)))
print("Lasso Regression:", "{:.3f}".format(np.mean(lasso_mse_all_runs)), "±", "{:.3f}".format(np.std(lasso_mse_all_runs)))
print("Ridge Regression:", "{:.3f}".format(np.mean(ridge_mse_all_runs)), "±", "{:.3f}".format(np.std(ridge_mse_all_runs)))
print("Random Forest:", "{:.3f}".format(np.mean(random_forest_mse_all_runs)), "±", "{:.3f}".format(np.std(random_forest_mse_all_runs))
)
# Out:
# Majority: 0.030 ± 0.016
# Mean: 0.029 ± 0.015
# LLMs: 0.032 ± 0.017
# GAN: 0.030 ± 0.016
# NDE: 0.030 ± 0.016
# Linear Regression: 0.030 ± 0.012
# Lasso Regression: 0.029 ± 0.015
# Ridge Regression: 0.029 ± 0.013
# Random Forest: 0.033 ± 0.012
